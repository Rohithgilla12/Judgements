# %%
import requests
from bs4 import BeautifulSoup

# %%
urls=[]
for i in range(35000):
    urls.append('http://judis.nic.in/hcs/list_new2.asp?FileName='+str(i)+'&Table_Main_Txt=cheordtext')

# %%
op=open('madras.txt','a')
j=0
for i in range(1135,len(urls)):
    ip=urls[i]
    try:
        r=requests.get(ip) 
        soup=BeautifulSoup(r.content,'html.parser')
        temp=soup.findAll('p')[0]
        op.write(temp.text)
        op.write('___'*10)
        j+=1
        print "Done with"+str(j)+"case(s)"
    except:
        pass
op.close()
# Out:
# Done with1case(s)
# Done with2case(s)
# Done with3case(s)
# Done with4case(s)
# Done with5case(s)
# Done with6case(s)
# Done with7case(s)
# Done with8case(s)
# Done with9case(s)
# Done with10case(s)
# Done with11case(s)
# Done with12case(s)
# Done with13case(s)
# Done with14case(s)
# Done with15case(s)
# Done with16case(s)
# Done with17case(s)
# Done with18case(s)
# Done with19case(s)
# Done with20case(s)
# Done with21case(s)
# Done with22case(s)
# Done with23case(s)
# Done with24case(s)
# Done with25case(s)
# Done with26case(s)
# Done with27case(s)
# Done with28case(s)
# Done with29case(s)
# Done with30case(s)
# Done with31case(s)
# Done with32case(s)
# Done with33case(s)
# Done with34case(s)
# Done with35case(s)
# Done with36case(s)
# Done with37case(s)
# Done with38case(s)
# Done with39case(s)
# Done with40case(s)
# Done with41case(s)
# Done with42case(s)
# Done with43case(s)
# Done with44case(s)
# Done with45case(s)
# Done with46case(s)
# Done with47case(s)
# Done with48case(s)
# ...

# %%
url='https://indiankanoon.org/search/?formInput=doctypes:supremecourt%20fromdate:1-1-2017%20todate:%2031-12-2017'

# %%
import requests
from bs4 import BeautifulSoup
r=requests.get(url)

# %%
soup=BeautifulSoup(r.content,'html.parser')

# %%
soup.prettify()
# Out:
# u'<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN"\n"http://www.w3.org/TR/html4/strict.dtd">\n<html>\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="content-type"/>\n  <link href="/static/jquery-ui.min.css" rel="stylesheet" type="text/css"/>\n  <link href="/static/jquery-ui.theme.min.css" rel="stylesheet" type="text/css"/>\n  <link href="/static/search_desktop_v14.css" rel="stylesheet" type="text/css"/>\n  <script type="text/javascript">\n   (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n  })(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\n\n      ga(\'create\', \'UA-87326-4\', \'auto\');\n      ga(\'require\', \'linkid\', \'linkid.js\');\n      ga(\'require\', \'displayfeatures\');\n      ga(\'send\', \'pageview\');\n  </script>\n  <title
# ...
